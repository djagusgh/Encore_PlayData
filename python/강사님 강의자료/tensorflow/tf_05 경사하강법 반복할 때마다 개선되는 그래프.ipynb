# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
my_data = []
for i in range(1000):
    x = np.random.normal(0, 1)
    y = 0.1 * x + np.random.normal(0, 0.05)
    my_data.append([x, y])

# my_data[:5]
x_data = [ v[0] for v in my_data ]
y_data = [ v[1] for v in my_data ]
plt.plot(x_data, y_data, 'ro')
plt.show()

# %%
W = tf.Variable(tf.random_uniform([1], 1, -1))
b = tf.Variable(tf.zeros([1])) ## b = 0
hypothesis = W * x_data + b

cost = tf.reduce_mean(tf.square(hypothesis - y_data))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.2)
train = optimizer.minimize(cost)

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

# %%
for step in range(10):
    print('step=', 'wW=', sess.run(W), 'cost=', sess.run(cost))
    sess.run(train)
    plt.plot(x_data, y_data, 'ro')
    plt.plot(x_data, sess.run(W)*x_data + sess.run(b))
    plt.show()

sess.close()
# Out:
# step= wW= [0.877043] cost= 0.65864575
# step= wW= [0.53962684] cost= 0.21274066
# step= wW= [0.348665] cost= 0.06996199
# step= wW= [0.24055699] cost= 0.024189435
# step= wW= [0.17933492] cost= 0.009495707
# step= wW= [0.14465289] cost= 0.0047716754
# step= wW= [0.12499864] cost= 0.0032503435
# step= wW= [0.11385641] cost= 0.0027594962
# step= wW= [0.10753722] cost= 0.002600799
# step= wW= [0.10395186] cost= 0.002549373
