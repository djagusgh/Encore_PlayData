# %%
# 예시

# %%
html_doc = """
<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(html_doc, 'html.parser')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c688ef736e7f> in <module>()
# ----> 1 soup = BeautifulSoup(html_doc, 'html.parser')
#
# NameError: name 'html_doc' is not defined

# %%
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
# 1. 로또 사이트에서 몇 회차인지 뽑음

# %%
url = "http://nlotto.co.kr/gameResult.do?method=byWin"
html = urlopen(url)
soup = BeautifulSoup(html, "lxml") # 'html.parser' 보다 속도가 빠름!
hoi = soup.find("h3", {"class":"result_title"})
str_hoi = hoi.strong.string

# %%
print(str_hoi, "회")
# Out:
# 831 회

# %%
# 2. 831회의 당첨 숫자 뽑아내는 코드

# %%
numbers =[]
p = soup.find("p", {"class":"number"})
imgs = p.findAll('img')
print("imgs : {}".format(imgs))
for img in imgs:
    numbers.append(img['alt'])  # alt tag -> 시각 장애인도 번호 뭔지 알 수 있게끔! 웹 접근성
bonus = numbers.pop(6)
print("numbers : {} ".format(numbers))
print("bonus : {}".format(bonus))
# Out:
# imgs : [<img alt="3" src="/img/common_new/ball_3.png"/>, <img alt="10" src="/img/common_new/ball_10.png"/>, <img alt="16" src="/img/common_new/ball_16.png"/>, <img alt="19" src="/img/common_new/ball_19.png"/>, <img alt="31" src="/img/common_new/ball_31.png"/>, <img alt="39" src="/img/common_new/ball_39.png"/>, <img alt="9" src="/img/common_new/ball_9.png"/>]
# numbers : ['3', '10', '16', '19', '31', '39']
# bonus : 9

# %%
url = "http://"

# %%
url = "http://www.skyscanner.com"
html = urlopen(url)
soup = BeautifulSoup(html, "lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
# <head>
# <script>!function(e){function r(r){r&&r.data&&r.data.boomr_mq&&(e.BOOMR_mq=e.BOOMR_mq||[],e.BOOMR_mq.push(r.data.boomr_mq))}e.addEventListener&&e.addEventListener("message",r);var a=e.navigator;a&&"serviceWorker"in a&&a.serviceWorker.addEventListener&&a.serviceWorker.addEventListener("message",r)}(window);</script>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale = 1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="#008ca8" name="theme-color"/>
# <meta content="#21c4d9" name="msapplication-TileColor"/>
# <link href="/android-chrome-manifest.json" rel="manifest"/>
# <title>Cheap Flights: Find Cheap Plane Tickets &amp; Flight Deals | Skyscanner</title>
# <link href="//api.mixpanel.com" rel="dns-prefetch"/>
# <link href="https://secure.skyscanner.net" rel="dns-prefetch"/>
# <link href="//www.google-analytics.com" rel="dns-prefetch"/>
# <link href="//cdn.mxpnl.com" rel="dns-prefetch"/>
# <link href="//www.googletagservices.com" rel="dns-prefetch"/>
# <link href="//analytics.skyscanner.net" rel="dns-prefetch"/>
# <link href="//s.go-mpulse.net" rel="dns-prefetch"/>
# <link href="https://www.skyscanner.com/" rel="canonical"/>
# <meta content="SKYPE_TOOLBAR_PARSER_COMPATIBLE" name="SKYPE_TOOLBAR"/>
# <meta content="3ccd97fca3bc5b05" name="y_key"/>
# <meta content="App" name="msApplication-ID"/>
# <meta content="Skyscanner.Skyscanner_623c9he0pwcym" name="msApplication-PackageFamilyName"/>
# <meta content="1.2.0.0" name="msApplication-MinVersion"/>
# <link href="//css.skyscnr.com/sttc/blackbird/static/css/main.514afb43.css" rel="stylesheet"/>
# <meta content="Search cheap flights with over 1200 sites at once and find the cheapest plane tickets. Compare all options and book direct with Delta &amp; American with no added fees. Save time by setting price alerts." name="description"/>
# <meta content="cheap flights, cheapest flights, flight deals, cheapest flight deals, airline flight deals, plane tickets, cheap plane tickets, cheap airline tickets, flight tickets, cheap flight, last minute cheap flights, last minute flights, airfare comparison, skyscanner" name="keywords"/>
# <link href="https://www.skyscanner.ae/" hreflang="en-AE" rel="alternate"/>
# <link href="https://www.skyscanner.at/" hreflang="de-AT" rel="alternate"/>
# <link href="https://www.skyscanner.com.au/" hreflang="en-AU" rel="alternate"/>
# <link href="https://www.skyscanner.com.br/" hreflang="pt-BR" rel="alternate"/>
# <link href="https://www.skyscanner.ca/" hreflang="en-CA" rel="alternate"/>
# <link href="https://www.skyscanner.ca/" hreflang="fr-CA" rel="alternate"/>
# <link href="https://www.skyscanner.ch/" hreflang="de-CH" rel="alternate"/>
# <link href="https://www.skyscanner.ch/" hreflang="fr-CH" rel="alternate"/>
# <link href="https://www.skyscanner.ch/" hreflang="it-CH" rel="alternate"/>
# <link href="https://www.skyscanner.cz/" hreflang="cs" rel="alternate"/>
# <link href="https://www.skyscanner.de/" hreflang="de" rel="alternate"/>
# <link href="https://www.skyscanner.dk/" hreflang="da" rel="alternate"/>
# <link href="https://www.skyscanner.es/" hreflang="es-ES" rel="alternate"/>
# <link href="https://www.skyscanner.fi/" hreflang="fi" rel="alternate"/>
# <link href="https://www.skyscanner.fr/" hreflang="fr" rel="alternate"/>
# <link href="https://www.skyscanner.gg/" hreflang="en-GG" rel="alternate"/>
# <link href="https://gr.skyscanner.com/" hreflang="el" rel="alternate"/>
# <link href="https://www.skyscanner.com.hk/" hreflang="zh-HK" rel="alternate"/>
# <link href="https://www.skyscanner.com.hk/" hreflang="en-HK" rel="alternate"/>
# <link href="https://www.skyscanner.hu/" hreflang="hu" rel="alternate"/>
# <link href="https://www.skyscanner.co.id/" hreflang="id" rel="alternate"/>
# <link href="https://www.skyscanner.ie/" hreflang="en-IE" rel="alternate"/>
# <link href="https://www.skyscanner.co.il/" hreflang="en-IL" rel="alternate"/>
# <link href="https://www.skyscanner.co.in/" hreflang="en-IN" rel="alternate"/>
# <link href="https://www.skyscanner.it/" hreflang="it" rel="alternate"/>
# <link href="https://www.skyscanner.jp/" hreflang="ja" rel="alternate"/>
# <link href="https://www.skyscanner.co.kr/" hreflang="ko" rel="alternate"/>
# <link href="https://www.espanol.skyscanner.com/" hreflang="es" rel="alternate"/>
# <link href="https://www.skyscanner.com.my/" hreflang="en-MY" rel="alternate"/>
# <link href="https://www.skyscanner.com.my/" hreflang="ms-MY" rel="alternate"/>
# <link href="https://www.skyscanner.nl/" hreflang="nl" rel="alternate"/>
# <link href="https://www.skyscanner.no/" hreflang="nb" rel="alternate"/>
# <link href="https://www.skyscanner.co.nz/" hreflang="en-NZ" rel="alternate"/>
# <link href="https://www.skyscanner.com.ph/" hreflang="en-PH" rel="alternate"/>
# <link href="https://www.skyscanner.com.ph/" hreflang="tl-PH" rel="alternate"/>
# <link href="https://www.skyscanner.pl/" hreflang="pl" rel="alternate"/>
# <link href="https://www.skyscanner.pt/" hreflang="pt" rel="alternate"/>
# <link href="https://www.skyscanner.ro/" hreflang="ro" rel="alternate"/>
# <link href="https://www.skyscanner.ru/" hreflang="ru" rel="alternate"/>
# <link href="https://www.skyscanner.se/" hreflang="sv" rel="alternate"/>
# <link href="https://www.skyscanner.com.sg/" hreflang="en-SG" rel="alternate"/>
# <link href="https://www.skyscanner.com.sg/" hreflang="ms-SG" rel="alternate"/>
# <link href="https://www.skyscanner.com.sg/" hreflang="zh-SG" rel="alternate"/>
# <link href="https://www.skyscanner.co.th/" hreflang="th" rel="alternate"/>
# <link href="https://www.skyscanner.com.tr/" hreflang="tr" rel="alternate"/>
# <link href="https://www.skyscanner.com.tw/" hreflang="zh-TW" rel="alternate"/>
# <link href="https://www.skyscanner.com.ua/" hreflang="uk" rel="alternate"/>
# <link href="https://www.skyscanner.com/" hreflang="en-US" rel="alternate"/>
# <link href="https://www.skyscanner.com/" hreflang="es-US" rel="alternate"/>
# <link href="https://www.skyscanner.com.vn/" hreflang="vi" rel="alternate"/>
# <link href="https://www.skyscanner.net/" hreflang="x-default" rel="alternate"/>
# <link href="android-app://net.skyscanner.android.main/skyscanner/home" rel="alternate"/>
# <meta content="https://www.skyscanner.com/sttc/blackbird/opengraph_solid.png" property="og:image"/>
# <meta content="256" property="og:image:width"/>
# <meta content="256" property="og:image:height"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="https://www.skyscanner.com/?utm_medium=social&amp;utm_campaign=addthis&amp;utm_source=facebook_us" property="og:url"/>
# <meta content="Skyscanner | Find the cheapest flights fast: save time, save money!" property="og:title"/>
# <meta content="Compare millions of flights, as well as car rental and hotels worldwide - for free! Skyscanner is the travel search site for savvy travelers." property="og:description"/>
# <meta content="product" property="og:type"/>
# <meta content="577860132331990" property="fb:pages"/>
# <meta content="7i-6D_2r9dL-xIlE5g89MTf-lFqgxjg9w6M4NUJpPdQ" property="google-site-verification"/>
# <meta content="0E3C71340522D93E54DBA582021C05FB" name="msvalidate.01"/>
# <!-- preload the React Blackbird is using -->
# <link as="script" crossorigin="anonymous" href="//js.skyscnr.com/sttc/shared-libs/react/react16.4.2.js" rel="preload"/>
# <link as="script" crossorigin="anonymous" href="//js.skyscnr.com/sttc/shared-libs/react-dom/react-dom16.4.2.js" rel="preload"/>
# <!-- preload the React search controls are using -->
# <link as="script" crossorigin="anonymous" href="//js.skyscnr.com/sttc/shared-libs/react/react15.5.4.js" rel="preload"/>
# <link as="script" crossorigin="anonymous" href="//js.skyscnr.com/sttc/shared-libs/react-dom/react-dom15.5.4.js" rel="preload"/>
# <link as="fetch" href="/dataservices/culture/cldr/v2.0/en-us/us/usd" rel="preload"/>
# <script>!function(){function o(n,i){if(n&&i)for(var r in i)i.hasOwnProperty(r)&&(void 0===n[r]?n[r]=i[r]:n[r].constructor===Object&&i[r].constructor===Object?o(n[r],i[r]):n[r]=i[r])}try{var n=decodeURIComponent("");if(n.length>0&&window.JSON&&"function"==typeof window.JSON.parse){var i=JSON.parse(n);void 0!==window.BOOMR_config?o(window.BOOMR_config,i):window.BOOMR_config=i}}catch(o){window.console&&"function"==typeof window.console.error&&console.error("mPulse: Could not parse configuration",o)}}();</script>
# <script>!function(e){var a="https://s.go-mpulse.net/boomerang/";if("False"=="True")e.BOOMR_config=e.BOOMR_config||{},e.BOOMR_config.PageParams=e.BOOMR_config.PageParams||{},e.BOOMR_config.PageParams.pci=!0,a="https://s2.go-mpulse.net/boomerang/";if(function(){function t(a){e.BOOMR_onload=a&&a.timeStamp||(new Date).getTime()}if(!e.BOOMR||!e.BOOMR.version&&!e.BOOMR.snippetExecuted){e.BOOMR=e.BOOMR||{},e.BOOMR.snippetExecuted=!0;var n,i,o,r=document.createElement("iframe");if(e.addEventListener)e.addEventListener("load",t,!1);else if(e.attachEvent)e.attachEvent("onload",t);r.src="javascript:void(0)",r.title="",r.role="presentation",(r.frameElement||r).style.cssText="width:0;height:0;border:0;display:none;",o=document.getElementsByTagName("script")[0],o.parentNode.insertBefore(r,o);try{i=r.contentWindow.document}catch(e){n=document.domain,r.src="javascript:var d=document.open();d.domain='"+n+"';void(0);",i=r.contentWindow.document}i.open()._l=function(){var e=this.createElement("script");if(n)this.domain=n;e.id="boomr-if-as",e.src=a+"QRHAF-VKPV6-ZTS8J-965A3-72Q93",BOOMR_lstart=(new Date).getTime(),this.body.appendChild(e)},i.write("<bo"+'dy onload="document._l();">'),i.close()}}(),"".length>0)if(e&&"performance"in e&&e.performance&&"function"==typeof e.performance.setResourceTimingBufferSize)e.performance.setResourceTimingBufferSize();!function(){if(BOOMR=e.BOOMR||{},BOOMR.plugins=BOOMR.plugins||{},!BOOMR.plugins.AK){var a={i:!1,av:function(a){var t="http.initiator";if(a&&(!a[t]||"spa_hard"===a[t])){var n=""=="true"?1:0,i="",o=void 0!==e.aFeoApplied?1:0;if(BOOMR.addVar({"ak.v":15,"ak.cp":"109768","ak.ai":"233543","ak.ol":"0","ak.cr":15,"ak.ipv":4,"ak.proto":"","ak.rid":"79f2fec","ak.r":32345,"ak.a2":n,"ak.m":"a","ak.n":"essl","ak.bpcip":"210.126.217.0","ak.cport":58058,"ak.gh":"23.59.72.79","ak.quicv":"","ak.tlsv":"tls1.2","ak.0rtt":"","ak.csrc":"-","ak.acc":"reno","ak.feo":o}),""!==i)BOOMR.addVar("ak.ruds",i)}},rv:function(){var e=["ak.bpcip","ak.cport","ak.cr","ak.csrc","ak.gh","ak.ipv","ak.m","ak.n","ak.ol","ak.proto","ak.quicv","ak.tlsv","ak.0rtt","ak.r","ak.acc"];BOOMR.removeVar(e)}};BOOMR.plugins.AK={init:function(){if(!a.i){var e=BOOMR.subscribe;e("before_beacon",a.av,null,null),e("onbeacon",a.rv,null,null),a.i=!0}return this},is_complete:function(){return!0}}}}()}(window);</script></head>
# <body>
# <script>
#       window["__internal"] = {
# "tagManagerProps": {"utid":"1a24e1aa-4635-4f03-afad-c0edd4f3ca19","originId":"US","isMobile":false,"isTablet":false,"isBrowser":false,"locale":"en-US","market":"US","currency":"USD","page":"home","category":"transport"},
# "featureTests": {"AAExperiment_V8":"a","AfsKeywordsSelection_V1":"b","DEAL_Default_To_Two_Guests_V3":"b","EcoItinerariesTerra_V12":"c","FLUX_GDT2791_SendPriceTraceToMixpanel_V6":"b","GDT3736_Month_View_Trip_Destination_V2":"a","HATCH_unlocked_deals_V5":"b","HFE_SocialValidation_V2":"b","Hfe_OfficialPartner_It2_V2":"b","Hfe_PricePerNight_V2":"b","Mexico_Etnio_Interview_Screener_01_V1":"b","OTR_ImageShare_UseDeepLinkGenerator_V9":"on","RailWidgetTerra_V5":"c","ShowCarHireHotelsHomeLink_Hide_25_01_2017_01_50_V1":"a","TCS_Send_Searching_Email_V4":"b","Trex_OCSearchControls_V41":"b","Trex_OCSearchControls_DayView_V9":"b","Trex_wider_autosuggest_V3":"b","change_optional_extra_title_V10":"b","dbook_basi_trafficcontrol_web_V1":"a","dbook_drag_trafficcontrol_all_web_V2":"a","dbook_flot_trafficcontrol_V12":"a","dbook_hhk__trafficcontrol_web_V3":"a","dbook_sexp_trafficcontrol_web_V5":"a","dbook_silk_trafficcontrol_web_V9":"a","dbook_sing_trafficcontrol_web_V11":"a","dbook_sune_trafficcontrol_web_V4":"a","fbw_new_style_itinerary_component_V5":"b","fps_lus_client_quote_service_split_traffic_V225":"b","fps_lus_mag_coverage_measure_V4":"enabled","fps_lus_qss_automatic_rules_V19":"a","fps_lus_quote_service_split_quote_pipeline_V68":"qps","fps_lus_send_quotes_to_slipstream_V25":"noexperiment","fps_mbmd_V11":"b","fps_multiple_fare_families_V12":"b","fps_quoteretrieval_aws_V115":"aws","fps_route_summary_traffic_shift_V6":"b","rts_wta_shadowtraffic_V400":"b"},
# "tagManagerVersion": "2.0.52",
# "strevdaRuntimeProps": {"culture":{"tld":"com","market":"US","currency":"USD","locale":"en-US","localeParentName":"en-US"},"containers":[],"pageName":"flights.homepage","adUnit":"home_page","topLevelDomain":"skyscanner.com","destinationType":"","isNewUser":true,"isLoggedIn":false,"utid":"1a24e1aa-4635-4f03-afad-c0edd4f3ca19","flightSearch":{"cabinClass":"Economy","adults":0,"children":0,"tripType":"one-way","outboundDate":"","inboundDate":"","origin":{},"destination":{}},"carHireSearch":{},"device":{"os":"unknown","isMobilePhone":false,"isTablet":false,"isBrowser":false,"browserName":"unknown"},"configurations":{"afsEnabled":true,"advert_booking_panel_inline":false,"advert_visibility_throttle":"250","experiments_targeting":"DeliveryServiceTraffic,PV57_BAadvertToBrandedDayView,Adx_value_test,Ads_Multilayout2","experiments_tracking":"Ads_HotelHouseInline_Experiment,ADS_InfiniteScroll_react","flights_inline_config":"{}","general_ads_enabled":true,"hotel_house_inline_creative_id":"CVE-a6144e2d-383c-4a35-8ec7-cf577ecebe16","loggingLevel":"error","ryanair_advertiser_id":"22594509","Ads_AppDownload_experiment":"","Ads_BrowseView_Inline_experiment":"","Ads_Show_CPM_Ribbon":"","Ads_Ryanair_Experiment":"","ShowCookieBanner":false,"afs_style_id":"1637922902","afs_channel_id":"3028470329","afs_number":"5","AirportTransfersEnabled":false,"ads_pqs_house_ad":true}},
# "strevdaRuntimeVersion": "1.0.483",
# "CultureSelectorVersion": "1.0.13",
# "inspirationShelvesEnabled": true,
# "inspirationShelvesComponentDetails": {"component":"inspiration-shelves","version":"0.0.22"},
# "publicPath": "\u002F\u002Fjs.skyscnr.com\u002Fsttc\u002Fblackbird\u002F",
# "culture": {"tld":"com","market":"US","currency":"USD","locale":"en-US","localeParentName":"en-US"},
# "inspirationShelvesParams": {"locale":"en-US","market":"US","remoteConfiguration":{"GrowthHacking":{"ShowDiscoveryShelvesAds":true,"ShowBrowseAlerts":false,"ShowHotelsReferral":false,"UseAkamaiImageManager":true,"ShowMapOnDiscoveryShelf":true,"UseSearchPatternService":true,"ShowEditorialContentOnDiscoveryShelves":true,"EnableLazyLoadingOfImagesOnDiscoveryShelves":true,"accountsUrl":"https:\u002F\u002Fsecure.skyscanner.net","UseAWSBrowseServiceEndPointOnShelves":true}},"originId":"US","originName":"United States","originCountryId":"US"},
# "searchControlsVersion": "0.0.281",
# "searchControlsParams": {"locale":"en-US","market":"US","currency":"USD","originId":"US","originName":"United States","originCountryId":"US"},
# "searchControlsContext": {"locale":"en-US","market":"US","currency":"USD","originId":"US","originName":"United States","originCountryId":"US"},
# "searchControlsConfig": {"HomepageandSearchControlsUI":{"FlightsGeneralSearchVariant":"single-best","XHRRumSamplingRate":"0.1","DebounceTime":"0","FlightsGeneralSearch":true,"ModalAutosuggest":false,"WiderAutosuggest":true,"ScrollableDatepicker":true},"FlightSearch":{"fss_sc_days_till_travel":"5","fss_sc_duration_of_travel":"7"}},
# "headerVersion": "0.4.121"
# };
# window["__Mpulse"] = {
# "pageid": "home",
# "microsite": "blackbird",
# "region": "ap-northeast-1"
# };
#     </script>
# <script crossorigin="anonymous" src="//js.skyscnr.com/sttc/blackbird/static/js/main.4cdaee2e.js"></script>
# <div class="pagecontent" id="pagewrap">
# <h1 class="heading">Find Cheap Flights and Flight Deals with Skyscanner</h1>
# <link href="//js.skyscnr.com/sttc/oc-registry/components/header/0.4.121/build/static/css/main.b86f8b97.css" rel="stylesheet"/>
# <script>window.HEADER_STATE = {"locale":"en-US","market":"US","currency":"USD","currencyLabel":"$ USD","activeTab":"airli","debug":false,"showPackagesTab":false,"showTabs":true,"useMaxWidth":false,"showBorder":false,"showLocaleCode":false,"showHeaderSearchBox":false,"showBackpackTouchMenu":true,"migrateFlightsHome":false,"userLoggedIn":false,"enableLoginButtonRedirects":false,"componentVersion":"0.4.121","showCultureSelector":true,"showOcCultureSelector":true,"strings":{"account_settings":"Account settings","buses":"Buses","car_hire":"Car Rental","change":"Change","change_language_currency":"Change language/currency","close":"Close","dynamic_packages":"Flight + Hotel","flights":"Flights","help_anchor_text":"Help","home_page_strap_line":"Cheap Flights with Skyscanner","hotels":"Hotels","login":"Log in","login_register":"Login / Register","logout_with_email":"Log out (@@email@@)","menu":"menu","news_area":"Travel features & news","price_alerts":"Price Alerts","recent_searches":"Recent searches","search":"Search","subscriptions":"Subscriptions","touch_menu_toggle":"Side menu toggle","user_account":"Account","your_skyscanner":"Your Skyscanner"},"urls":{"flights":"https://www.skyscanner.com/","car_hire":"https://www.skyscanner.com/car-rental","hotels":"https://www.skyscanner.com/hotels"}};</script>
# <script crossorigin="anonymous" defer="" src="//js.skyscnr.com/sttc/oc-registry/components/header/0.4.121/build/static/js/main.e8c75446.js"></script>
# <div id="header-root"><header class="Header-1_1R8" data-reactroot=""><div class="Header__wrapper-2KwQq clearfix Header__wrapper--set-width-2srwX"><nav class="SecondaryNav-3MUje"><ul class="SecondaryNav__list-1lEyp"><li class="SecondaryNav__help-19EmT SecondaryNav__item-25SJ- SecondaryNav__item--small-_0Qtf"><a class="bpk-link-143_C" href="https://help.skyscanner.net/hc/en-us" id="ss-header-links-faq" rel="noopener noreferrer" target="_blank">Help</a></li><li class="SecondaryNav__culture-selector-TeNdM culture-info SecondaryNav__item-25SJ-" id="culture-info"><button class="bpk-button-30cpF bpk-button--secondary-lyMj0" type="button"><img alt="US" class="CultureSelectorButton__country-flag-3XdiO" src="https://images.skyscnr.com/images/country/flag/header/us.png" title="US"/> <!-- --> <!-- -->$ USD</button></li><li class="SecondaryNav__account-2N-Uf SecondaryNav__item-25SJ-" id="login-button-nav-item"><button class="bpk-button-30cpF bpk-button--secondary-lyMj0" type="button"><span class="login" id="authentication-link">Log in</span></button></li><li class="SecondaryNav__menu-393l9 toggle-touch-menu SecondaryNav__item-25SJ-" id="toggle-touch-menu"><div><button aria-label="Side menu toggle" class="TouchMenu__button-5XDtn"><svg class="TouchMenu__icon-2IA4F bpk-icon--rtl-support-6bwD-" height="24" style="width:1.5rem;height:1.5rem" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M20 8H4c-.6 0-1-.4-1-1s.4-1 1-1h16c.6 0 1 .4 1 1s-.4 1-1 1zm1 4c0-.6-.4-1-1-1H4c-.6 0-1 .4-1 1s.4 1 1 1h16c.6 0 1-.4 1-1zm0 5c0-.6-.4-1-1-1H4c-.6 0-1 .4-1 1s.4 1 1 1h16c.6 0 1-.4 1-1z"></path></svg></button></div></li></ul></nav><div class="Header__logo-wrapper-26Akq" id="identity"><a class="Logo-38wHj" href="/"><svg class="bpk-logo bpk-logo__inline Logo__svg-l3cXE" viewbox="0 0 211 36" xmlns="http://www.w3.org/2000/svg"><path d="M70.187 14.115a.577.577 0 0 1-.765.365c-.969-.373-2.065-.64-3.09-.64-1.764 0-3.426.53-3.426 2.296 0 .954.53 1.449 2.227 1.98l1.236.387c2.473.776 3.533 1.907 3.533 4.096 0 3.778-2.65 6.358-7.452 6.358-1.887 0-3.501-.296-4.87-.773-.333-.116-.493-.486-.394-.825l.565-1.96c.094-.325.456-.479.77-.353 1.237.5 2.608.839 3.822.839 2.156 0 3.673-.742 3.673-2.474 0-1.024-.706-1.411-2.296-1.907l-1.343-.423c-2.367-.777-3.427-2.19-3.427-4.45 0-3.851 3.216-5.933 7.454-5.933 1.275 0 2.732.285 3.947.702.335.114.497.486.394.824l-.558 1.891zm8.347-10.082c.33 0 .575.3.514.623l-2.6 13.436c2.45-1.787 4.59-3.887 6.48-6.324a1.27 1.27 0 0 1 1.007-.494h2.828c.272 0 .423.307.267.53-1.859 2.621-3.986 5.04-6.237 6.993l3.582 9.017a.434.434 0 0 1-.402.592h-3.005a.915.915 0 0 1-.854-.595l-2.465-6.717c-.662.446-1.346.859-2.049 1.237l-1.046 5.451a.772.772 0 0 1-.753.624h-2.582a.523.523 0 0 1-.512-.624l4.49-23.126a.768.768 0 0 1 .756-.624h2.581v.001zm13.213 7.24c.33 0 .577.302.514.626l-1.75 9.019c-.142.67-.283 1.518-.283 2.332 0 1.058.6 1.766 2.013 1.766 1.378 0 3.001-.601 4.203-1.73l2.245-11.388a.774.774 0 0 1 .756-.624h2.582c.329 0 .575.3.511.625l-2.314 11.88c-.283 1.377-.6 2.931-.882 4.168C97.999 33.528 95.456 36 90.369 36c-1.12 0-2.235-.14-3.205-.4a.687.687 0 0 1-.494-.818l.442-1.804a.616.616 0 0 1 .738-.461c.733.175 1.571.304 2.343.304 3.005 0 4.768-1.272 5.404-4.732l.25-1.308c-1.307 1.13-3.252 1.872-5.087 1.872-2.968 0-4.557-1.483-4.557-3.85 0-1.413.283-2.968.6-4.59l1.61-8.313a.773.773 0 0 1 .755-.626h2.579v-.001zm23.306 2.855a.577.577 0 0 1-.765.366c-.968-.374-2.066-.642-3.09-.642-1.764 0-3.424.532-3.424 2.297 0 .954.527 1.449 2.223 1.98l1.237.387c2.472.776 3.533 1.907 3.533 4.097 0 3.778-2.65 6.358-7.452 6.358-1.885 0-3.502-.297-4.868-.774-.334-.116-.494-.486-.397-.825l.567-1.96c.093-.325.457-.479.77-.353 1.236.5 2.607.839 3.82.839 2.155 0 3.674-.742 3.674-2.474 0-1.024-.705-1.411-2.294-1.907l-1.346-.423c-2.365-.777-3.424-2.19-3.424-4.45 0-3.851 3.214-5.933 7.454-5.933 1.275 0 2.73.285 3.946.702.332.114.494.486.393.824l-.557 1.891zm15.075.387a.526.526 0 0 1-.735.323c-.93-.425-1.982-.668-3.181-.668-3.743 0-6.007 3.216-6.007 7.313.036 2 ...
# <div class="homecontent" id="home-container" style="background-image: url(//content.skyscnr.com/6bf5a29ce130132f28e912434f295b76/canada-lake-feb.jpg?crop=2000px:559px&amp;quality=80)">
# <div class="wrap-homecontent">
# <link href="//js.skyscnr.com/sttc/oc-registry/components/flights-search-controls/0.0.281/build/static/css/main.ba3855ce.css" rel="stylesheet"/>
# <div id="flights-search-controls-root"><div class="App-37BK7" data-reactroot=""><div class="flights-sc-wrapper-3j0dG"><form><div><div><label class="bpk-radio-29Pvv TripTypeSelector-2JInq"><input checked="" class="bpk-radio__input-1WNhX" id="fsc-trip-type-selector-return" name="trip-type-selector" type="radio"/><div class="bpk-radio__circle-3iEts"></div>Roundtrip</label><label class="bpk-radio-29Pvv TripTypeSelector-2JInq"><input class="bpk-radio__input-1WNhX" id="fsc-trip-type-selector-one-way" name="trip-type-selector" type="radio"/><div class="bpk-radio__circle-3iEts"></div>One way</label><label class="bpk-radio-29Pvv TripTypeSelector-2JInq"><input class="bpk-radio__input-1WNhX" id="fsc-trip-type-selector-multi-destination" name="trip-type-selector" type="radio"/><div class="bpk-radio__circle-3iEts"></div>Multi-city</label></div></div><div class="SingleDestControls-2wsUo"><div class="places-wrapper-2bPPN places-wrapper-oneline-a6q8v"><div class="origin-wrapper-3DU8U origin-wrapper-oneline-O6bj_"><div class="LocationSelector-3WIxW"><label class="bpk-label-3kiqK form-label-pYNx1" for="origin-fsc-search">From</label><div aria-expanded="false" aria-haspopup="listbox" aria-owns="react-autowhatever-origin-fsc-search" class="bpk-autosuggest__container" role="combobox"><input aria-autocomplete="list" aria-controls="react-autowhatever-origin-fsc-search" aria-invalid="false" autocomplete="off" class="bpk-input-R6x4G fsc-large-above-tablet-3NddW fsc-docked-first-above-mobile-1KUbo fsc-location-input-2Jtp_" id="origin-fsc-search" name="origin-fsc-search" placeholder="Country, city or airport" type="text" value=""/><div class="bpk-autosuggest__suggestions-container-1AI3q" id="react-autowhatever-origin-fsc-search" role="listbox"></div></div></div><label class="bpk-checkbox-2gl_e bpk-checkbox--white-28H-F flights-sc-checkbox-36W7m flights-sc-checkbox-oneline-18VMh"><input class="bpk-checkbox__input-2snZh" name="originFlexible" tabindex="2" type="checkbox"/><svg class="bpk-checkbox__icon-1Kasz" height="18" style="width:.75rem;height:.75rem" viewbox="0 0 24 24" width="18" xmlns="http://www.w3.org/2000/svg"><path d="M9.4 20c-.5 0-.9-.2-1.3-.5l-5.8-5.1c-.4-.4-.5-1-.1-1.4l1.3-1.5c.4-.4 1-.5 1.4-.1l4 3.5c.2.1.4.1.6 0l9.2-10.5c.4-.4 1-.5 1.4-.1l1.5 1.3c.4.4.5 1 .1 1.4L10.9 19.3c-.4.5-.9.7-1.5.7z"></path></svg><span class="bpk-checkbox__label-qxEfU bpk-checkbox__label--small-2l71u">Add nearby airports</span></label></div><div class="switch-wrapper-W2L9P switch-wrapper-oneline-d_XF1"><label class="bpk-label-3kiqK form-label-2vvuw"> </label><div class="SwitchButton-1LStY"><button aria-label="Switch origin and destination" class="SwitchButton__button-19yj1" tabindex="2" type="button"><svg height="18" style="width:1.125rem;height:1.125rem" viewbox="0 0 24 24" width="18" xmlns="http://www.w3.org/2000/svg"><path d="M9.1 11.2V9.5H15c.8 0 1.5-.7 1.5-1.5s-.7-1.5-1.5-1.5H9.1V4.8c0-.6-.6-.9-1.1-.7L2.4 7.3c-.5.3-.5 1 0 1.3L8 11.9c.5.3 1.1-.1 1.1-.7zm12.5 4.1L16 12.1c-.5-.3-1.1.1-1.1.7v1.7H9c-.8 0-1.5.7-1.5 1.5s.7 1.5 1.5 1.5h5.9v1.7c0 .6.6.9 1.1.7l5.6-3.2c.5-.3.5-1.1 0-1.4z"></path></svg></button></div></div><div class="destination-wrapper-3jUaz destination-wrapper-oneline-3lMdF"><div class="LocationSelector-3WIxW"><label class="bpk-label-3kiqK form-label-pYNx1" for="destination-fsc-search">To</label><div aria-expanded="false" aria-haspopup="listbox" aria-owns="react-autowhatever-destination-fsc-search" class="bpk-autosuggest__container" role="combobox"><input aria-autocomplete="list" aria-controls="react-autowhatever-destination-fsc-search" aria-invalid="false" autocomplete="off" class="bpk-input-R6x4G fsc-large-above-tablet-3NddW fsc-docked-middle-above-tablet-1iZwT fsc-docked-last-on-tablet-vWch9 fsc-location-input-2Jtp_" id="destination-fsc-search" name="destination-fsc-search" placeholder="Country, city or airport" type="text" value=""/><div class="bpk-autosuggest__suggestions-container-1AI3q" id="react-autowhatever-destination-fsc-search" role="listbox" ...
# <script>window['flights-search-controls'] = { props: {"locale":"en-US","market":"US","autosuggestBaseUrl":"","rootNodeSelector":"#pagewrap","useComponentRegistry":true,"scaffolding":false,"componentVersion":"0.0.281","oneLine":true,"strings":{"ktxtPriceAlerts_DirectFlightsOnly":"Non-stop flights only","ktxtSearchControls_AddLeg":"Add another flight","ktxtSearchControls_AddNearbyAirport":"Add nearby airports","ktxtSearchControls_Adults":"Adults","ktxtSearchControls_AdultsSingular":"adult","ktxtSearchControls_Autosuggest_DistanceFrom":"@@distance@@ km from @@place@@, @@country@@","ktxtSearchControls_Autosuggest_DistanceFrom_Miles":"@@distance@@ miles from @@place@@, @@country@@","ktxtSearchControls_BtnCancel":"Cancel","ktxtSearchControls_CabinClassTerm_Business":"Business class","ktxtSearchControls_CabinClassTerm_Economy":"Economy","ktxtSearchControls_CabinClassTerm_First":"First-class","ktxtSearchControls_CabinClassTerm_PremiumEconomy":"Premium economy","ktxtSearchControls_CabinClassTerm_SelectPromptTitle":"We can only show Economy prices for this search.","ktxtSearchControls_CabinClassTerm_Title":"Cabin class","ktxtSearchControls_CantDecide":"Can't decide where?","ktxtSearchControls_CheapestMonth":"Cheapest month","ktxtSearchControls_Children":"Children","ktxtSearchControls_CountryCityAirportPlaceholder":"Country, city or airport","ktxtSearchControls_Datepicker_CompareAcrossWholeMonth":"Compare across a whole month:","ktxtSearchControls_Datepicker_SpecificDate":"Specific date","ktxtSearchControls_DatesOutOfSequence":"Please enter a valid date. Flights must depart after the preceding flight has landed.","ktxtSearchControls_DepartureDate":"Departure date","ktxtSearchControls_Done":"Done","ktxtSearchControls_EconomyOnly":"To see Business and First Class options, please tell us your exact dates and/or destination city.","ktxtSearchControls_EnterValidDate":"Please enter a valid date.","ktxtSearchControls_EnterValidDestination":"Please enter a valid destination.","ktxtSearchControls_EnterValidOrigin":"Please enter a valid origin.","ktxtSearchControls_EverywhereSuggestion_SubHeading":"Click here to search Everywhere","ktxtSearchControls_EverywhereSuggestion_SubHeading_Mobile":"Tap here to search Everywhere","ktxtSearchControls_From":"From","ktxtSearchControls_MapLink_Map":"Map","ktxtSearchControls_MultiCity":"Multi-city","ktxtSearchControls_OneWay":"One way","ktxtSearchControls_Passengers_adultRange":"16+ years","ktxtSearchControls_Passengers_childAge":"Age of child @@childNumber@@","ktxtSearchControls_Passengers_childRange":"0-15 years","ktxtSearchControls_Passengers_childrenValidation":"Please specify ages for all children.","ktxtSearchControls_Passengers_decreaseNumberAdults":"Decrease number of adults","ktxtSearchControls_Passengers_decreaseNumberChildren":"Decrease number of children","ktxtSearchControls_Passengers_increaseNumberAdults":"Increase number of adults","ktxtSearchControls_Passengers_increaseNumberChildren":"Increase number of children","ktxtSearchControls_Passengers_infantValidation":"Only 1 child (aged 0-2) per adult is allowed","ktxtSearchControls_Passengers_legal1":"Your age at time of travel must be valid for the age category booked. Airlines have restrictions on under 18s traveling alone.","ktxtSearchControls_Passengers_legal2":"Age limits and policies for traveling with children may vary so please check with the airline before booking.","ktxtSearchControls_Passengers_selectAge":"Select age","ktxtSearchControls_Return":"Roundtrip","ktxtSearchControls_ReturnDate":"Return date","ktxtSearchControls_SearchFlights":"Search flights","ktxtSearchControls_Searching":"Searching for flights","ktxtSearchControls_SwitchOriginDestination":"Switch origin and destination","ktxtSearchControls_To":"To","ktxtSearchControls_TravellersAndCabinClassTitle":"Cabin Class & Travelers","ktxtSearchControls_Travellers_Plural":"travelers","ktxtSearchControls_as_any":"Any","ktxtSearchControls_as_everywhere":"Everywhere","ktxtSearchControls_fi ...
# <script crossorigin="anonymous" src="//js.skyscnr.com/sttc/oc-registry/components/flights-search-controls/0.0.281/build/static/js/main.cce9d8ed.js"></script>
# </div>
# </div>
# <div class="inspiration-shelves-wrapper">
# <script defer="">window.SHELVES_PROPS = {"version":"0.0.22","locale":"en-US"};</script>
# <script crossorigin="anonymous" defer="" src="//js.skyscnr.com/sttc/oc-registry/components/inspiration-shelves/0.0.22/build/static/js/main.2ef4b410.js"></script>
# <div class="inspiration-wrap">
# <link href="//css.skyscnr.com/sttc/gadget/inspiration/0.1.33/static/inspirationTimeline/inspirationTimeline.min.css" rel="stylesheet" type="text/css"/>
# <div id="timeline-outer">
# <div class="wrap clearfix">
# <div class="inspiration-timeline">
# <ul class="timeline">
# <li class="timeline__block">
# <div class="dot timeline-foreground"></div>
# <div class="timeline-head">
# <h2> </h2>
# <time class="time"><span></span></time>
# <div class="origin">
# <label for="inspiration-timeline-origin"></label>
# <input autocomplete="off" class="inline-edit" id="inspiration-timeline-origin" tabindex="1" type="text" value=""/>
# </div>
# </div>
# <div class="shelf timeline-middleground loading" id="shelf-1">
# <div class="shelf-tiles">
# <div class="tile loading half full indent">
# <a>
# <div class="content"></div>
# </a>
# </div><div class="tile loading quarter indent-wrap">
# <a>
# <div class="content"></div>
# </a>
# </div><div class="tile loading quarter">
# <a>
# <div class="content"></div>
# </a>
# </div>
# </div>
# </div>
# <div class="alternative-link" data-index="0">
# <a class="everywhere-link" href=""></a>
# <a class="map-link" href=""></a>
# </div>
# </li>
# <li class="timeline__custom-slot--inactive">
# </li>
# <li class="timeline__block">
# <div class="dot timeline-foreground"></div>
# <div class="timeline-head">
# <h2> </h2>
# <time class="time"><span></span></time>
# </div>
# <div class="shelf timeline-middleground loading" id="shelf-2">
# <div class="shelf-tiles">
# <div class="tile loading half full indent">
# <a>
# <div class="content"></div>
# </a>
# </div><div class="tile loading quarter indent-wrap">
# <a>
# <div class="content"></div>
# </a>
# </div><div class="tile loading quarter">
# <a>
# <div class="content"></div>
# </a>
# </div>
# </div>
# </div>
# <div class="alternative-link" data-index="1">
# <a class="everywhere-link" href=""></a>
# <a class="map-link" href=""></a>
# </div>
# </li>
# <li class="timeline__block">
# <div class="dot timeline-foreground"></div>
# <div class="timeline-head">
# <h2> </h2>
# <time class="time" datetime="2014-08-28"><span>28 August 2016 - 30 August 2016</span></time>
# </div>
# <div class="shelf timeline-middleground loading" id="shelf-3">
# <div class="shelf-tiles">
# <div class="tile loading third full indent">
# <a>
# <div class="content"></div>
# </a>
# </div><div class="tile loading third indent-wrap">
# <a>
# <div class="content"></div>
# </a>
# </div><div class="tile loading third">
# <a>
# <div class="content"></div>
# </a>
# </div>
# </div>
# </div>
# <div class="alternative-link" data-index="2">
# <a class="everywhere-link" href=""></a>
# <a class="map-link" href=""></a>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
#   ﻿﻿﻿
#   <script type="text/javascript">
#     window.Skyscanner = window.Skyscanner || {};
#     Skyscanner.inspiration = { version: '0.1.33' };
#   </script>
# <script defer="" src="//js.skyscnr.com/sttc/gadget/inspiration/0.1.33/static/inspirationTimeline/localised/inspirationTimeline.en-US.min.js"></script>
# </div>
# <style>
#   .inspiration-wrap {
#     margin: 0 auto;
#     width: 1048px;
#   }
#
#   @media screen and (max-width: 1090px) {
#     .inspiration-wrap {
#       width: 100%;
#     }
#   }
# </style>
# </div>
# <div id="inspiration-shelf-react"></div>
# <div id="confidence-container">
# <section class="ConfidencePanels-1OmKT" data-reactroot=""><article class="ConfidencePanel-WTumW"><img alt="searchWorld" class="ConfidenceImage-1-sAk" src="//js.skyscnr.com/sttc/blackbird/static/media/search_world.a0f0dec4.svg"/><h3 class="bpk-text-3UEzO bpk-text--lg-M4yUR ConfidencePanel__heading-mG-m_"><span>What is Skyscanner?</span></h3><span class="bpk-text-3UEzO bpk-text--base-gnVBs"><span><span>Skyscanner finds you the cheapest flights by comparing millions of flight options. Aside from plane tickets, we also compare hotels and car rental prices.</span></span></span></article><article class="ConfidencePanel-WTumW"><img alt="appPromo" class="ConfidenceImage-1-sAk" src="//js.skyscnr.com/sttc/blackbird/static/media/app_promo.a07a2eff.svg"/><h3 class="bpk-text-3UEzO bpk-text--lg-M4yUR ConfidencePanel__heading-mG-m_"><span>Find cheap flights with the <a href="https://skyscanner.app.link/A0KO4SeTSN">Skyscanner Travel App</a></span></h3><span class="bpk-text-3UEzO bpk-text--base-gnVBs"><span><span>Search for cheap airline tickets, hotels, &amp; car rental with our award-winning <a href="https://skyscanner.app.link/A0KO4SeTSN">travel app</a>. Search everywhere, find the best time to book, and set price alerts.</span></span></span></article><article class="ConfidencePanel-WTumW"><img alt="free" class="ConfidenceImage-1-sAk" src="//js.skyscnr.com/sttc/blackbird/static/media/free.febc4eab.svg"/><h3 class="bpk-text-3UEzO bpk-text--lg-M4yUR ConfidencePanel__heading-mG-m_"><span>Skyscanner is free!</span></h3><span class="bpk-text-3UEzO bpk-text--base-gnVBs"><span>When you find cheap tickets and click to book, we link you through directly to the airline or travel agent. No hidden charges, no added fees. So you get the best deals every time!</span></span></article><article class="ConfidencePanel-WTumW"><img alt="priceAlerts" class="ConfidenceImage-1-sAk" src="//js.skyscnr.com/sttc/blackbird/static/media/price_alerts.f270f520.svg"/><h3 class="bpk-text-3UEzO bpk-text--lg-M4yUR ConfidencePanel__heading-mG-m_"><span>Find the Cheapest Flights with Skyscanner's Flight Deals</span></h3><span class="bpk-text-3UEzO bpk-text--base-gnVBs"><span><div><span>Stay up to date on the latest deals with Skyscanner's <a href="https://www.skyscanner.com/tips-and-inspiration/last-minute-flights-how-to-find-extremely-cheap-last-minute-flight-deals">last minute flight deals</a> and <a href="https://www.skyscanner.com/tips-and-inspiration/deals/daily-flights-deals">daily flight deals</a></span></div></span></span></article></section>
# </div>
# <link href="//js.skyscnr.com/sttc/oc-registry/components/links-pack/0.0.15/build/static/css/main.81605e6b.css" rel="stylesheet"/>
# <div id="links-pack-root">
# <section class="App-25ORK" data-reactroot=""><h2 class="bpk-text-2qfBn bpk-text--xl-2P-qW bpk-text--bold-3TvwT App__header-xincb">Plan your perfect trip</h2><h3 class="bpk-text-2qfBn bpk-text--base-FRTB4 App__subheader-CFhvZ">Search Flights, Hotels &amp; Car Rental to our most popular destinations</h3><aside class="App__aside-3Ts6U"><h4 class="bpk-text-2qfBn bpk-text--lg-2U8UL bpk-text--bold-3TvwT App__verticalheader-3qaG_"><div class="App__icon-1cu8h"><svg height="24" style="width:1.5rem;height:1.5rem" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M17.8 20.1l.6-.6c.2-.2.3-.5.2-.8l-2.2-9.3 4.1-4.2c.5-.5.5-1.3 0-1.9-.5-.5-1.4-.5-1.9 0l-4.2 4.1-9.1-2c-.3-.1-.6 0-.8.2l-.6.6c-.4.4-.3 1.1.2 1.4l7.2 3.2-3.7 3.7-2.3-.8c-.3-.1-.6 0-.8.2L3 15.2l4.2 1.6L8.8 21l1.3-1.5c.2-.2.3-.6.2-.8l-.8-2.3 3.7-3.7 3.2 7.2c.3.5 1 .6 1.4.2z"></path></svg></div>Flights</h4><h4 class="bpk-text-2qfBn bpk-text--lg-2U8UL bpk-text--bold-3TvwT App__verticalheader-3qaG_"><div class="App__icon-1cu8h"><svg height="24" style="width:1.5rem;height:1.5rem" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M8 12c-1.1 0-2-.9-2-2s.9-2 2-2 2 .9 2 2-.9 2-2 2m11-3.9h-6c-1.1 0-2 .9-2 2V12h10v-1.9c0-1.1-.9-2-2-2m3 5.9c0-.6-.4-1-1-1H5V5.5C5 4.7 4.3 4 3.5 4S2 4.7 2 5.5v13c0 .8.7 1.5 1.5 1.5S5 19.3 5 18.5V16h14v2.5c0 .8.7 1.5 1.5 1.5s1.5-.7 1.5-1.5V14z"></path></svg></div>Hotels</h4><h4 class="bpk-text-2qfBn bpk-text--lg-2U8UL bpk-text--bold-3TvwT App__verticalheader-3qaG_"><div class="App__icon-1cu8h"><svg height="24" style="width:1.5rem;height:1.5rem" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M3 20c0 .5.5 1 1 1h2c.5 0 1-.5 1-1v-2H3v2zm14 0c0 .5.5 1 1 1h2c.5 0 1-.5 1-1v-2h-4v2zm1.2-15.1C17.8 3.8 17 3 15.8 3H8.1c-.9 0-1.9.7-2.2 1.9L4 10.3c-.6.3-1 1-1 1.7v5h18v-5c0-.7-.4-1.4-1-1.7l-1.8-5.4zm-10.8.7c.1-.4.4-.6.8-.6h7.6c.4 0 .7.3.8.6L18 10H6l1.4-4.4zM6.5 15c-.8 0-1.5-.7-1.5-1.5S5.7 12 6.5 12s1.5.7 1.5 1.5S7.3 15 6.5 15zm11 0c-.8 0-1.5-.7-1.5-1.5s.7-1.5 1.5-1.5 1.5.7 1.5 1.5-.7 1.5-1.5 1.5z"></path></svg></div>Car Rental</h4></aside><div class="App__lists-2gmV9"><ul class="App__unorderedlist-2zoz3"><li class="App__item-ei-97"><h5 class="bpk-text-2qfBn bpk-text--lg-2U8UL App__mobileHeader--TQh1">New York</h5><ul class="App__links-1xqbh"><li class="App__linkItem-3z3oR"><a class="bpk-link-gIT5c App__linkText-24FG7" href="https://www.skyscanner.com/flights-to/nyca/cheap-flights-to-new-york.html"><span class="bpk-text-2qfBn bpk-text--sm-2VHCH bpk-text--bold-3TvwT App__mobileLink-2zxBA">Flights</span><span class="bpk-text-2qfBn bpk-text--base-FRTB4 App__desktopLink-3l847">Flights to New York</span></a></li></ul><ul class="App__links-1xqbh"><li class="App__linkItem-3z3oR"><a class="bpk-link-gIT5c App__linkText-24FG7" href="https://www.skyscanner.com/hotels/united-states/new-york-hotels/ci-27537542"><span class="bpk-text-2qfBn bpk-text--sm-2VHCH bpk-text--bold-3TvwT App__mobileLink-2zxBA">Hotels</span><span class="bpk-text-2qfBn bpk-text--base-FRTB4 App__desktopLink-3l847">Hotels in New York</span></a></li></ul><ul class="App__links-1xqbh"><li class="App__linkItem-3z3oR"><a class="bpk-link-gIT5c App__linkText-24FG7" href="https://www.skyscanner.com/car-rental-in/nyca/car-rental-in-new-york.html"><span class="bpk-text-2qfBn bpk-text--sm-2VHCH bpk-text--bold-3TvwT App__mobileLink-2zxBA">Car Rental</span><span class="bpk-text-2qfBn bpk-text--base-FRTB4 App__desktopLink-3l847">Car Rental in New York</span></a></li></ul></li><li class="App__item-ei-97"><h5 class="bpk-text-2qfBn bpk-text--lg-2U8UL App__mobileHeader--TQh1">Los Angeles</h5><ul class="App__links-1xqbh"><li class="App__linkItem-3z3oR"><a class="bpk-link-gIT5c App__linkText-24FG7" href="https://www.skyscanner.com/flights-to/laxa/cheap-flights-to-los-angeles.html"><span class="bpk-text-2qfBn bpk-text--sm-2VHCH bpk-text--bold-3TvwT App__mobileLink-2zxBA">Flights</span><span class="bpk-text-2qfBn bpk-text--base-FRTB4 App__desktopLink-3l847">Flights to ...
# </div>
# <script>window['links-pack'] = { props: {"placeLinks":{"New York":{"flights":"https://www.skyscanner.com/flights-to/nyca/cheap-flights-to-new-york.html","hotels":"https://www.skyscanner.com/hotels/united-states/new-york-hotels/ci-27537542","carhire":"https://www.skyscanner.com/car-rental-in/nyca/car-rental-in-new-york.html"},"Los Angeles":{"flights":"https://www.skyscanner.com/flights-to/laxa/cheap-flights-to-los-angeles.html","hotels":"https://www.skyscanner.com/hotels/united-states/los-angeles-hotels/ci-27536211","carhire":"https://www.skyscanner.com/car-rental-in/laxa/car-rental-in-los-angeles.html"},"Las Vegas":{"flights":"https://www.skyscanner.com/flights-to/las/cheap-flights-to-las-vegas-mccarran-airport.html","hotels":"https://www.skyscanner.com/hotels/united-states/las-vegas-hotels/ci-27542715","carhire":"https://www.skyscanner.com/car-rental-in/lasa/car-rental-in-las-vegas.html"},"Miami":{"flights":"https://www.skyscanner.com/flights-to/mia/cheap-flights-to-miami-international-airport.html","hotels":"https://www.skyscanner.com/hotels/united-states/miami-hotels/ci-27536644","carhire":"https://www.skyscanner.com/car-rental-in/miaa/car-rental-in-miami.html"},"Boston":{"flights":"https://www.skyscanner.com/flights-to/bos/cheap-flights-to-boston-logan-international-airport.html","hotels":"https://www.skyscanner.com/hotels/united-states/boston-hotels/ci-27539525","carhire":"https://www.skyscanner.com/car-rental-in/bosa/car-rental-in-boston.html"},"Mexico City":{"flights":"https://www.skyscanner.com/flights-to/mex/cheap-flights-to-mexico-city-juarez-international-airport.html","hotels":"https://www.skyscanner.com/hotels/mexico/mexico-city-hotels/ci-39151418","carhire":"https://www.skyscanner.com/car-rental-in/mexa/car-rental-in-mexico-city.html"},"Denver":{"flights":"https://www.skyscanner.com/flights-to/den/cheap-flights-to-denver-international-airport.html","hotels":"https://www.skyscanner.com/hotels/united-states/denver-hotels/ci-27536589","carhire":"https://www.skyscanner.com/car-rental-in/dena/car-rental-in-denver.html"},"Chicago":{"flights":"https://www.skyscanner.com/flights-to/chia/cheap-flights-to-chicago.html","hotels":"https://www.skyscanner.com/hotels/united-states/chicago-hotels/ci-27544891","carhire":"https://www.skyscanner.com/car-rental-in/chia/car-rental-in-chicago.html"},"Orlando":{"flights":"https://www.skyscanner.com/flights-to/orlb/cheap-flights-to-orlando.html","hotels":"https://www.skyscanner.com/hotels/united-states/orlando-hotels/ci-27542899","carhire":"https://www.skyscanner.com/car-rental-in/orlb/car-rental-in-orlando.html"},"New Delhi":{"flights":"https://www.skyscanner.com/flights-to/del/cheap-flights-to-new-delhi-airport.html","hotels":"https://www.skyscanner.com/hotels/india/new-delhi-hotels/ci-27540706","carhire":"https://www.skyscanner.com/car-rental-in/idel/car-rental-in-new-delhi.html"}},"strings":{"city-breaks-confidence_content":"<ul><li>Last month, Skyscanner helped over 50 million users find their flights and hotels</li><li>We compare 100s of airlines and travel agents to find you the best deal.</li><li>We're free! Skyscanner finds you the best price for your weekend getaway, without charging you a penny.</li></ul>","city-breaks-confidence_title":"Internationally trusted, no hidden fees.","city-breaks-header_title":"<strong>{city}</strong> weekend getaways","city-breaks-index-meta_description":"Looking for a short weekend getaway? At Skyscanner we compare all major airlines, hotel providers and travel agents to find the best weekend getaway deals available.","city-breaks-index-meta_title":"Weekend Getaways | Skyscanner","city-breaks-meta_description":"Searching for a cheap getaway to {city}? Skyscanner searches hundreds of hotel and flights partners to find you the perfect weekend getaway in {city}.","city-breaks-meta_title":"Discover Cheap {city} Weekend Getaways | Skyscanner","component_best-deal_flight-and-hotel-from":"Flight + Hotel from {price}","component_city-break-links_all-cit ...
# <script crossorigin="anonymous" defer="" src="//js.skyscnr.com/sttc/oc-registry/components/links-pack/0.0.15/build/static/js/main.adb8a600.js"></script>
# <footer id="footer">
# ...
# <script crossorigin="anonymous" defer="" src="//js.skyscnr.com/sttc/oc-registry/components/footer/0.3.7/build/static/js/main.45232d5c.js"></script>
# </footer>
# <link href="//js.skyscnr.com/sttc/oc-registry/components/footer-flags/0.0.27/build/static/css/main.aa20e661.css" rel="stylesheet"/>
# <div id="footer-flags-root">
# <div class="FooterFlags-ePnVE" data-reactroot=""><div class="FooterFlags__heading-3ASZb"><h3 class="bpk-text-3bay1 bpk-text--lg-2OCA3">International Sites</h3></div><ul class="bpk-list-2XgYs FooterFlags__content-3smqF"><li class="bpk-list__item-cEpNg FooterFlag-3gieA uk-1HOSE"><a class="bpk-link-3s-AT FooterFlag__links-dt8jZ" href="https://www.skyscanner.net/?market=UK&amp;locale=en-GB" rel="alternate"><span>Cheap flights</span></a></li><li class="bpk-list__item-cEpNg FooterFlag-3gieA au-1S1QU"><a class="bpk-link-3s-AT FooterFlag__links-dt8jZ" href="https://www.skyscanner.com.au/?market=AU&amp;locale=en-GB" rel="alternate"><span>Australia - Cheap flights</span></a></li><li class="bpk-list__item-cEpNg FooterFlag-3gieA br-1D51p"><a class="bpk-link-3s-AT FooterFlag__links-dt8jZ" href="https://www.skyscanner.com.br/?market=BR&amp;locale=pt-BR" rel="alternate"><span>Brasil - passagens aéreas</span></a></li><li class="bpk-list__item-cEpNg FooterFlag-3gieA ca-3oWSl"><a class="bpk-link-3s-AT FooterFlag__links-dt8jZ" href="https://www.skyscanner.ca/?market=CA&amp;locale=en-US" rel="alternate"><span>Canada - flights</span></a></li><li class="bpk-list__item-cEpNg FooterFlag-3gieA cn-1jhNd"><a class="bpk-link-3s-AT FooterFlag__links-dt8jZ" href="http://www.tianxun.com/?market=CN&amp;locale=zh-CN" rel="alternate"><span>中国 - 机票</span></a></li><li class="bpk-list__item-cEpNg FooterFlag-3gieA in-3R_hr"><a class="bpk-link-3s-AT FooterFlag__links-dt8jZ" href="https://www.skyscanner.co.in/?market=IN&amp;locale=en-GB" rel="alternate"><span>India - Flight tickets</span></a></li><li class="bpk-list__item-cEpNg FooterFlag-3gieA jp-2ovhu"><a class="bpk-link-3s-AT FooterFlag__links-dt8jZ" href="https://www.skyscanner.jp/?market=JP&amp;locale=ja-JP" rel="alternate"><span>日本 - 航空券</span></a></li><li class="bpk-list__item-cEpNg FooterFlag-3gieA mx-2Fr0E"><a class="bpk-link-3s-AT FooterFlag__links-dt8jZ" href="https://www.espanol.skyscanner.com/?market=MX&amp;locale=es-MX" rel="alternate"><span>México - vuelos</span></a></li><li class="bpk-list__item-cEpNg FooterFlag-3gieA ru-3BhQ_"><a class="bpk-link-3s-AT FooterFlag__links-dt8jZ" href="https://www.skyscanner.ru/?market=RU&amp;locale=ru-RU" rel="alternate"><span>Россия - авиабилеты</span></a></li><li class="bpk-list__item-cEpNg FooterFlag-3gieA us-2tuR6"><a class="bpk-link-3s-AT FooterFlag__links-dt8jZ" href="https://www.skyscanner.com/?market=US&amp;locale=en-US" rel="alternate"><span>USA - flights</span></a></li></ul><select aria-invalid="false" class="bpk-select-3SRb0 FooterFlags__dropDownList-SCvz3" id="FooterFlagsSelect" name="FooterFlagsSelect"><option class="FooterFlagListElement-1UYmt" selected="" value="">Please select an option</option><option class="FooterFlagListElement-1UYmt" value="https://www.skyscanner.net/?market=UK&amp;locale=en-GB">(GB)Cheap flights</option><option class="FooterFlagListElement-1UYmt" value="https://www.skyscanner.com.au/?market=AU&amp;locale=en-GB">(AU)Australia - Cheap flights</option><option class="FooterFlagListElement-1UYmt" value="https://www.skyscanner.com.br/?market=BR&amp;locale=pt-BR">(BR)Brasil - passagens aéreas</option><option class="FooterFlagListElement-1UYmt" value="https://www.skyscanner.ca/?market=CA&amp;locale=en-US">(CA)Canada - flights</option><option class="FooterFlagListElement-1UYmt" value="http://www.tianxun.com/?market=CN&amp;locale=zh-CN">(CN)中国 - 机票</option><option class="FooterFlagListElement-1UYmt" value="https://www.skyscanner.co.in/?market=IN&amp;locale=en-GB">(IN)India - Flight tickets</option><option class="FooterFlagListElement-1UYmt" value="https://www.skyscanner.jp/?market=JP&amp;locale=ja-JP">(JP)日本 - 航空券</option><option class="FooterFlagListElement-1UYmt" value="https://www.espanol.skyscanner.com/?market=MX&amp;locale=es-MX">(MX)México - vuelos</option><option class="FooterFlagListElement-1UYmt" value="https://www.skyscanner.ru/?market=RU&amp;locale=ru-RU">(RU)Россия - авиабилеты</option><option class="FooterFlagListElement-1UYmt"  ...
# </div>
# <script>window['footer-flags'] = { props: {"debug":false,"strings":{"heading":"International Sites","selectedOptionLabel":"Please select an option"},"footerFlags":[{"id":"uk-en-gb","market":"UK","url":"https://www.skyscanner.net/?market=UK&locale=en-GB","linkLabel":"Cheap flights","dropDownItemLabel":"(GB)Cheap flights"},{"id":"au-en-gb","market":"AU","url":"https://www.skyscanner.com.au/?market=AU&locale=en-GB","linkLabel":"Australia - Cheap flights","dropDownItemLabel":"(AU)Australia - Cheap flights"},{"id":"br-pt-br","market":"BR","url":"https://www.skyscanner.com.br/?market=BR&locale=pt-BR","linkLabel":"Brasil - passagens aéreas","dropDownItemLabel":"(BR)Brasil - passagens aéreas"},{"id":"ca-en-us","market":"CA","url":"https://www.skyscanner.ca/?market=CA&locale=en-US","linkLabel":"Canada - flights","dropDownItemLabel":"(CA)Canada - flights"},{"id":"cn-zh-cn","market":"CN","url":"http://www.tianxun.com/?market=CN&locale=zh-CN","linkLabel":"中国 - 机票","dropDownItemLabel":"(CN)中国 - 机票"},{"id":"in-en-gb","market":"IN","url":"https://www.skyscanner.co.in/?market=IN&locale=en-GB","linkLabel":"India - Flight tickets","dropDownItemLabel":"(IN)India - Flight tickets"},{"id":"jp-ja-jp","market":"JP","url":"https://www.skyscanner.jp/?market=JP&locale=ja-JP","linkLabel":"日本 - 航空券","dropDownItemLabel":"(JP)日本 - 航空券"},{"id":"mx-es-mx","market":"MX","url":"https://www.espanol.skyscanner.com/?market=MX&locale=es-MX","linkLabel":"México - vuelos","dropDownItemLabel":"(MX)México - vuelos"},{"id":"ru-ru-ru","market":"RU","url":"https://www.skyscanner.ru/?market=RU&locale=ru-RU","linkLabel":"Россия - авиабилеты","dropDownItemLabel":"(RU)Россия - авиабилеты"},{"id":"us-en-us","market":"US","url":"https://www.skyscanner.com/?market=US&locale=en-US","linkLabel":"USA - flights","dropDownItemLabel":"(US)USA - flights"}]} };</script>
# <script crossorigin="anonymous" defer="" src="//js.skyscnr.com/sttc/oc-registry/components/footer-flags/0.0.27/build/static/js/main.77ae54eb.js"></script>
# <div class="legal-info">
# <p class="legal-info__copyright">
#           © Skyscanner Ltd 2002-2018
#         </p>
# </div>
# </div>
# <script crossorigin="anonymous" data-data='{"culture":{"tld":"com","market":"US","currency":"USD","locale":"en-US","localeParentName":"en-US"},"gaLinkedDomains":["skyscanner.net","skyscanneraffiliate.net","hotels.skyscanner.com","redirect.datahc.com","www.goeverywhere.sg","bus.skyscanner.co.in","skyscanner.squarespace.com","perfectflight.skyscanner.com","vaiovunque.it","lomejorespana.skyscanner.es","pinkandblack-skyscanner.net","sommergewinnspiel.skyscanner.de","bienvenue.skyscanner.fr","abdbileti.skyscanner.com.tr","damonandjo.skyscanner.com","goeverywhere.skyscanner.com","smiles.skyscanner.com","skyscanner.tpromo.it","www.oisbende.skyscanner.com.tr","miami.skyscanner.com","codevoyagers.com","winnen.skyscanner.nl","www.kazan.skyscanner.com.tr","www.apideeplink.com","dach.skyscanner.de","inspirationlounge.skyscanner.com","ambassadors.skyscanner.com","www.skyscanner.it","www.skyscanner.no","www.skyscanner.com.vn","www.skyscanner.co.id","www.skyscanner.es","www.skyscanner.co.nz","www.skyscanner.ae","www.skyscanner.com.tw","www.tianxun.com","www.skyscanner.com.au","www.skyscanner.ro","www.skyscanner.ca","www.skyscanner.cz","www.skyscanner.ie","www.skyscanner.fr","www.skyscanner.co.in","www.skyscanner.com.my","www.skyscanner.at","www.skyscanner.com.sg","www.skyscanner.co.il","www.skyscanner.fi","www.skyscanner.de","www.skyscanner.com.ph","www.skyscanner.com.tr","www.skyscanner.jp","www.skyscanner.nl","www.skyscanner.dk","gr.skyscanner.com","www.skyscanner.hu","www.skyscanner.net","www.skyscanner.com","www.skyscanner.com.hk","www.skyscanner.ru","www.skyscanner.pl","www.skyscanner.co.th","www.skyscanner.gg","www.espanol.skyscanner.com","www.skyscanner.se","www.skyscanner.ch","www.skyscanner.com.br","www.skyscanner.com.ua","www.skyscanner.pt","www.skyscanner.co.kr"],"featureTestsString":"AAExperiment_V8-a&amp;&amp;AfsKeywordsSelection_V1-b&amp;&amp;DEAL_Default_To_Two_Guests_V3-b&amp;&amp;EcoItinerariesTerra_V12-c&amp;&amp;FLUX_GDT2791_SendPriceTraceToMixpanel_V6-b&amp;&amp;GDT3736_Month_View_Trip_Destination_V2-a&amp;&amp;HATCH_unlocked_deals_V5-b&amp;&amp;HFE_SocialValidation_V2-b&amp;&amp;Hfe_OfficialPartner_It2_V2-b&amp;&amp;Hfe_PricePerNight_V2-b&amp;&amp;Mexico_Etnio_Interview_Screener_01_V1-b&amp;&amp;OTR_ImageShare_UseDeepLinkGenerator_V9-on&amp;&amp;RailWidgetTerra_V5-c&amp;&amp;ShowCarHireHotelsHomeLink_Hide_25_01_2017_01_50_V1-a&amp;&amp;TCS_Send_Searching_Email_V4-b&amp;&amp;Trex_OCSearchControls_V41-b&amp;&amp;Trex_OCSearchControls_DayView_V9-b&amp;&amp;Trex_wider_autosuggest_V3-b&amp;&amp;change_optional_extra_title_V10-b&amp;&amp;dbook_basi_trafficcontrol_web_V1-a&amp;&amp;dbook_drag_trafficcontrol_all_web_V2-a&amp;&amp;dbook_flot_trafficcontrol_V12-a&amp;&amp;dbook_hhk__trafficcontrol_web_V3-a&amp;&amp;dbook_sexp_trafficcontrol_web_V5-a&amp;&amp;dbook_silk_trafficcontrol_web_V9-a&amp;&amp;dbook_sing_trafficcontrol_web_V11-a&amp;&amp;dbook_sune_trafficcontrol_web_V4-a&amp;&amp;fbw_new_style_itinerary_component_V5-b&amp;&amp;fps_lus_client_quote_service_split_traffic_V225-b&amp;&amp;fps_lus_mag_coverage_measure_V4-enabled&amp;&amp;fps_lus_qss_automatic_rules_V19-a&amp;&amp;fps_lus_quote_service_split_quote_pipeline_V68-qps&amp;&amp;fps_lus_send_quotes_to_slipstream_V25-noexperiment&amp;&amp;fps_mbmd_V11-b&amp;&amp;fps_multiple_fare_families_V12-b&amp;&amp;fps_quoteretrieval_aws_V115-aws&amp;&amp;fps_route_summary_traffic_shift_V6-b&amp;&amp;rts_wta_shadowtraffic_V400-b","featureTests":{"AAExperiment_V8":"a","AfsKeywordsSelection_V1":"b","DEAL_Default_To_Two_Guests_V3":"b","EcoItinerariesTerra_V12":"c","FLUX_GDT2791_SendPriceTraceToMixpanel_V6":"b","GDT3736_Month_View_Trip_Destination_V2":"a","HATCH_unlocked_deals_V5":"b","HFE_SocialValidation_V2":"b","Hfe_OfficialPartner_It2_V2":"b","Hfe_PricePerNight_V2":"b","Mexico_Etnio_Interview_Screener_01_V1":"b","OTR_ImageShare_UseDeepLinkGenerator_V9":"on","RailWidgetTerra_V5":"c","ShowCarHireHotelsHomeLink_Hide_25_01_2017_01_50_V1":"a","TCS_Send_Searching_Email_V4":"b","Trex_OC ...
# <script>window.TAG_MANAGER_PROPS = {"staticPath":"\u002F\u002Fjs.skyscnr.com\u002Fsttc\u002Foc-registry\u002Fcomponents\u002Fjs-tag-manager\u002F2.0.52\u002F","version":"2.0.52","urls":[],"names":["perimeterx","criteo","comscore","usabilla","google-adwords","facebookconversion","google-conversion","gdn-conversion-points","salesforce-dmp"]};</script>
# <script crossorigin="anonymous" defer="" src="//js.skyscnr.com/sttc/oc-registry/components/js-tag-manager/2.0.52/build/static/js/main.05c97b60.js"></script>
# <div id="tag-manager-react"></div>
# <script async="" crossorigin="anonymous" data-ismicrosite="true" data-translations="{&quot;Carhire_AFS_Query1&quot;:&quot;Car Hire @@location@@&quot;,&quot;Flights_AFS_Query1&quot;:&quot;Flights from @@from@@ to @@to@@&quot;,&quot;Flights_AFS_Query10&quot;:&quot;Flight deals to @@to@@&quot;,&quot;Flights_AFS_Query11&quot;:&quot;Flights to @@to@@&quot;,&quot;Flights_AFS_Query12&quot;:&quot;Low cost flights to @@to@@&quot;,&quot;Flights_AFS_Query2&quot;:&quot;Cheap flights from @@from@@ to @@to@@&quot;,&quot;Flights_AFS_Query3&quot;:&quot;Flight deals from @@from@@ to @@to@@&quot;,&quot;Flights_AFS_Query4&quot;:&quot;Low cost flights from @@from@@ to @@to@@&quot;,&quot;Flights_AFS_Query5&quot;:&quot;@@from@@ flights to @@to@@&quot;,&quot;Flights_AFS_Query6&quot;:&quot;Flight deals to @@to@@&quot;,&quot;Flights_AFS_Query7&quot;:&quot;Airfare from @@from@@ to @@to@@&quot;,&quot;Flights_AFS_Query8&quot;:&quot;Airfare to @@to@@ from @@from@@&quot;,&quot;Flights_AFS_Query9&quot;:&quot;Cheap flights to @@to@@&quot;,&quot;Flights_AFS_Query_From&quot;:&quot;Flights from&quot;,&quot;Flights_AFS_Query_FromTo&quot;:&quot;Flights from @@departure@@ to @@destination@@&quot;,&quot;Flights_AFS_Query_To&quot;:&quot;Flights to&quot;,&quot;ktx2Stops&quot;:&quot;2 stops&quot;,&quot;ktxt3Stops&quot;:&quot;3 stops&quot;,&quot;ktxt4Stops&quot;:&quot;4 stops&quot;,&quot;ktxt5Stops&quot;:&quot;5 stops&quot;,&quot;ktxtAd&quot;:&quot;Ad&quot;,&quot;ktxtAdSurveyCancel&quot;:&quot;Cancel&quot;,&quot;ktxtAdSurveyContinue&quot;:&quot;Continue&quot;,&quot;ktxtAdSurveyResponse_1&quot;:&quot;I don’t like the advertiser or price shown&quot;,&quot;ktxtAdSurveyResponse_2&quot;:&quot;The ad is not useful or interferes with my search&quot;,&quot;ktxtAdSurveyResponse_3&quot;:&quot;There is an error or problem with the ad&quot;,&quot;ktxtAdsSurveyError&quot;:&quot;Please select an option from the list&quot;,&quot;ktxtAdsSurveyStart&quot;:&quot;Why don't you want to see this?&quot;,&quot;ktxtBookFlight&quot;:&quot;Book flight&quot;,&quot;ktxtBookFlightFrom&quot;:&quot;Book flight from {money}&quot;,&quot;ktxtBookHotel&quot;:&quot;Book your hotel&quot;,&quot;ktxtBusiness&quot;:&quot;Business&quot;,&quot;ktxtDirect&quot;:&quot;Non-stop&quot;,&quot;ktxtDownload&quot;:&quot;Download&quot;,&quot;ktxtDynamicAdFlightAndHotelLabel&quot;:&quot;Flight + Hotel&quot;,&quot;ktxtDynamicAdPerPersonLabel&quot;:&quot;per person&quot;,&quot;ktxtDynamicAdTotalLabel&quot;:&quot;{0} total&quot;,&quot;ktxtEconomy&quot;:&quot;Economy&quot;,&quot;ktxtFirst&quot;:&quot;First&quot;,&quot;ktxtFlightsArrivalTime&quot;:&quot;@@time@@ (+1)&quot;,&quot;ktxtFlightsDynamicAdBookButton&quot;:&quot;Book&quot;,&quot;ktxtFlightsDynamicAdFromLabel&quot;:&quot;from&quot;,&quot;ktxtFlightsDynamicAdLoadingMessage&quot;:&quot;Check prices and save&quot;,&quot;ktxtFlightsDynamicAdOneWayLabel&quot;:&quot;one-way&quot;,&quot;ktxtFlightsDynamicAdPersonOneWayLabel&quot;:&quot;per person one-way&quot;,&quot;ktxtFlightsDynamicAdPersonReturnLabel&quot;:&quot;per person roundtrip&quot;,&quot;ktxtFlightsDynamicAdReturnLabel&quot;:&quot;roundtrip&quot;,&quot;ktxtFlightsDynamicAdTermsAndConditions&quot;:&quot;Terms and Conditions apply&quot;,&quot;ktxtFlightsDynamicAdToLabel&quot;:&quot;to&quot;,&quot;ktxtFlightsItinerary&quot;:&quot;@@starttime@@ (@@stops@@) @@endtime@@&quot;,&quot;ktxtFromLocation&quot;:&quot;from @@location@@&quot;,&quot;ktxtFromPrice&quot;:&quot;from @@price@@&quot;,&quot;ktxtHotelsDynamicAdHotelsLabel&quot;:&quot;{0} Hotels&quot;,&quot;ktxtHotelsDynamicAdNightLabel&quot;:&quot;night&quot;,&quot;ktxtHotelsDynamicAdStarsLabel&quot;:&quot;stars&quot;,&quot;ktxtHotelsInlineShowAll&quot;:&quot;Show all hotels&quot;,&quot;ktxtInlineAdSponsored&quot;:&quot;Sponsored&quot;,&quot;ktxtIntentmediaCompare&quot;:&quot;Compare&quot;,&quot;ktxtIntentmediaHeadline&quot;:&quot;Compare against Skyscanner&quot;,&quot;ktxtNumberBookingsLastMonth&quot;:&quot;@@bookings@@ bookings last month&quot;,&quot;ktxtNumberExitsLas ...
# <link href="https://css.skyscnr.com/sttc/strevda-runtime/css/setup.615cba89d543f449194728d03563baa0.css" rel="stylesheet"/>
# <script>window.oc=window.oc||{};oc.renderedComponents=oc.renderedComponents||{};oc.renderedComponents["strevda-runtime"]="1.0.483";</script>
# <link href="//js.skyscnr.com/sttc/oc-registry/components/xsell-tooltip/0.0.26/build/static/css/main.bd1ddaa4.css" rel="stylesheet"/>
# <div id="xsell-tooltip-root"></div>
# <script>window['xsell-tooltip'] = { props: {"scaffolding":false,"strings":{"title":"More than just flights","content":"Do you need a hotel for your @@s_highlight@@@@city@@@@e_highlight@@ trip?","close":"Not interested","more":"Yes, show me"},"target_id":"skhot"} };</script>
# <script src="//js.skyscnr.com/sttc/oc-registry/components/xsell-tooltip/0.0.26/build/static/js/main.0342fd1c.js"></script>
# </body>
# </html>

# %%
a = [4,3,5] # 답
b = [1,3,4] # 사용자 입력
n = []

strike = 0
ball = 0

for i in range(len(a)):
    if a[i] == b[i]:
        strike += 1
    elif b[i] in a:
        ball += 1

print(strike)
print(ball)
# Out:
# 1
# 1

# %%
# Out:
# [4, 7, 5, 1, 3, 9]
