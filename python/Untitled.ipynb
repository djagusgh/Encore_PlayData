# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
# 서울 -> 오사카 크롤링

# %%
url = """
https://www.skyscanner.co.kr/transport/flights/sela/osaa/181107/?adults=1&children=0&adultsv2=1&childrenv2=&infants=0&cabinclass=economy&rtn=0&preferdirects=false&outboundaltsenabled=false&inboundaltsenabled=false&ref=home#results

"""#results"
html = urlopen(url)
soup = BeautifulSoup(html, "lxml") # 'html.parser' 보다 속도가 빠름!

# %%
soup
"""
hoi = soup.find("h3", {"class":"result_title"})
str_hoi = hoi.strong.string
"""
# Out:
# <!DOCTYPE html>
# <html lang="ko-KR">
# <head>
# <script>!function(e){function r(r){r&&r.data&&r.data.boomr_mq&&(e.BOOMR_mq=e.BOOMR_mq||[],e.BOOMR_mq.push(r.data.boomr_mq))}e.addEventListener&&e.addEventListener("message",r);var a=e.navigator;a&&"serviceWorker"in a&&a.serviceWorker.addEventListener&&a.serviceWorker.addEventListener("message",r)}(window);</script>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale = 1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="#008ca8" name="theme-color"/>
# <meta content="#21c4d9" name="msapplication-TileColor"/>
# <link href="/android-chrome-manifest.json" rel="manifest"/>
# <title>저가 항공편 출발지: 서울 목적지: 오사카 스카이스캐너 제공</title>
# <link href="//api.mixpanel.com" rel="dns-prefetch"/>
# <link href="https://secure.skyscanner.net" rel="dns-prefetch"/>
# <link href="//www.google-analytics.com" rel="dns-prefetch"/>
# ...

# %%
money = soup.find("li", {"class" : "day-list-item ItinerariesContainer__dayListItem-sWySG"}) # {"class":"CTASection__price-2bc7h price"}

# %%
print(money)
# Out:
# None
